# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %% [markdown]
# ## 1 Comparing the two ‘dialects’

# %% [markdown]
# ### 1.1 Some nomenclature

# %%
#one figure can have multiple axis

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### 1.2 We need some data.

# %%
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

# %% [markdown]
# ### 1.3 Here comes the comparison

# %%
plt.plot(x, cos_x, label='cos x')
plt.plot(x, sin_x, label='sin x')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(x, cos_x, label='cos x')
ax.plot(x, sin_x, label='sin x')
ax.legend()
plt.show()

# %%
#use pyplot interface for quick and dirty plots

# %%
#use OO interface for more complex plots that 
#demand control and finesse

# %% [markdown]
# ## 2 Using the OO Interface

# %% [markdown]
# ### 2.1 Getting ax

# %%
fig, ax = plt.subplots(nrows=2,ncols=1)

# %% [markdown]
# ### 2.2 What is ax

# %%
type(ax)
#ax is a numpy array
# Out:
# numpy.ndarray

# %%
ax.shape
#contain 2 elemnts
# Out:
# (2,)

# %%
type(ax[0])
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
type(ax[1])
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
#both are matplotlib axis

# %% [markdown]
# ### 2.3 Plots in a column

# %%
ax[0].plot(x, cos_x, label='cos x')

# %%
ax[1].plot(x, sin_x, label='sin x')

# %%
#use ax[] to locate different graphs

# %%
fig, ax = plt.subplots(nrows=2,ncols=1)
ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')
plt.show()

# %% [markdown]
# ### 2.4 Legends

# %%
fig, ax = plt.subplots(nrows=2,ncols=1)
ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')
for a in ax:
    a.legend()
    a.grid(alpha=.25)
plt.show()

# %% [markdown]
# ### 2.5 Tweaks

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 10),  
                       sharex=True)
#5-->横向 10-->纵向

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 10), 
                       sharex=True)
ax[1].set_xlabel('$x$')
#use set_xlabel() with the OO interface
#NOT xlabel()
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 10), 
                       sharex=True)
ax[1].set_xlabel('$x$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].fill_between(x, 0, sin_x, alpha=.25)
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 10), 
                       sharex=True)
ax[1].set_xlabel('$x$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].fill_between(x, 0, sin_x, alpha=.25)
fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(10,5), 
                       sharex=True)
ax[1].set_xlabel('$x$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].fill_between(x, 0, sin_x, alpha=.25)
fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(10, 5),  
                       sharex=True)
ax[0].plot(x, cos_x, label=r'$\cos(x)$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].plot(x, sin_x, label=r'$\sin(x)$')
ax[1].fill_between(x, 0, sin_x, alpha=.25)

for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)

ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()

plt.show()

# %% [markdown]
# ## 3 More rows and columns

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(10, 4),
                       sharex='col', sharey='col')

# 总结：array顺序先左右后上下
top_left, top_right, bottom_left, bottom_right = ax.flatten()

x1 = np.linspace(0, 10, 100)
x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1))
top_right.plot(x2, 2*np.ones_like(x2))
bottom_left.plot(x1, 3*np.ones_like(x1))
bottom_right.plot(x2, 4**np.ones_like(x2))

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.1 Using ax

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(10, 4),
                       sharex='col', sharey='col')

x1 = np.linspace(0, 10, 100)
x2 = np.linspace(10, 20, 100)

ax[0, 0].plot(x1, np.ones_like(x1))
ax[0, 1].plot(x2, 2*np.ones_like(x2))
ax[1, 0].plot(x1, 3*np.ones_like(x1))
ax[1, 1].plot(x2, 4**np.ones_like(x2))

plt.tight_layout()
plt.show()

# %%
top_left=ax[0, 0]
top_right=ax[0, 1]
bottom_left=ax[1, 0]
bottom_right=ax[1, 1]

# %%
top_left, top_right, bottom_left, bottom_right = ax.flatten()

# %%
#the above 2 are used to make ax assigning easier
#(ways are concluded in More rows and columns)

# %% [markdown]
# ### 3.2 Sharing axes

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(10, 4))
top_left, top_right, bottom_left, bottom_right = ax.flatten()

x1 = np.linspace(0, 10, 100)
x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1))
top_right.plot(x2, 2*np.ones_like(x2))
bottom_left.plot(x1, 3*np.ones_like(x1))
bottom_right.plot(x2, 4**np.ones_like(x2))

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
plt.show()

# %%
# True	Makes all the AXES use the SAME RANGE.
# col	Use the same range for all the COLUMNS
# row	Use the same range for all the ROWS

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(10, 4),
                       sharex=True, sharey='row')
top_left, top_right, bottom_left, bottom_right = ax.flatten()

x1 = np.linspace(0, 10, 100)
x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1))
top_right.plot(x2, 2*np.ones_like(x2))
bottom_left.plot(x1, 3*np.ones_like(x1))
bottom_right.plot(x2, 4**np.ones_like(x2))

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
plt.show()

# %%
# most correct option 
# highlights the story 
# you are trying to convey with your plot

# %% [markdown]
# ### 3.3 Accessing all axes

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(10, 4),
                       sharex='col', sharey='col')

top_left, top_right, bottom_left, bottom_right = ax.flatten()

x1 = np.linspace(0, 10, 100)
x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1))
top_right.plot(x2, 2*np.ones_like(x2))
bottom_left.plot(x1, 3*np.ones_like(x1))
bottom_right.plot(x2, 4**np.ones_like(x2))

top_left.grid(alpha=.25)
top_right.grid(alpha=.25)
bottom_left.grid(alpha=.25)
bottom_right.grid(alpha=.25)

plt.tight_layout()
plt.show()

# %%
#Above one inefficient
#Below one efficient

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(10, 4),
                       sharex='col', sharey='col')

top_left, top_right, bottom_left, bottom_right = ax.flatten()

x1 = np.linspace(0, 10, 100)
x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1))
top_right.plot(x2, 2*np.ones_like(x2))
bottom_left.plot(x1, 3*np.ones_like(x1))
bottom_right.plot(x2, 4**np.ones_like(x2))

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4 Other useful plots

# %% [markdown]
# ### 4.1 Histograms

# %%
data = {}

filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_all.csv'
data['All'] = np.loadtxt(filename, skiprows=1)

filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_nus.csv'
data['NUS'] = np.loadtxt(filename, skiprows=1)

plt.style.use('bmh')

plt.hist([data['All'], data['NUS']],
         bins=50,                     
         label=['All', 'NUS']
         )
plt.xlabel('Mean of Basic Montly Eraning (S$)')
plt.ylabel('Number of Students')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.2 Scatter plots

# %%
data = {}
for label in ['All', 'NUS']:
    filename = f'sg-gov-graduate-employment-survey_basic_monthly_mean_{label.lower()}.csv'
    data[label] = np.loadtxt(filename, skiprows=1)

plt.style.use('seaborn-darkgrid')

for label, numbers in data.items():
    x = range(len(numbers))
    y = numbers
    plt.scatter(x, y, label=label, alpha=.5)

plt.xlabel('Position in the list')
plt.ylabel('Mean of Basic Montly Eraning (S$)')
plt.legend()
plt.show()
# Out:
# /var/folders/dv/y80dl5ss4r14zprs098k9rnr0000gn/T/ipykernel_948/3079979024.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ### 4.3 Bar charts

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.values())

plt.style.use('ggplot')
plt.bar(majors, numbers)
#the above 2 are the keys for bar chart format!
plt.xlabel('Majors')
plt.ylabel('Number of Students')

plt.show()

# %% [markdown]
# ### 4.4 Pie charts

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.values())

plt.style.use('fivethirtyeight')
plt.pie(numbers, 
        labels=majors,
        autopct='%1.1f%%',   
        # Take Note on how to format the percentages
        startangle=-90   
        #starting from horizontally pointing down
        )
plt.title('Percentage of each major')
plt.show()

# %% [markdown]
# ## Exercise 1 :  Plotting data from files

# %%
#Given version:

# %%
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharey='row')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1, color='g', alpha=.125)
axes[0, 0].set_xlabel('Angle (radians)')
axes[0, 0].text(0, 0, 'I am [0, 0]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, cos_x, -2, color='r', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_ylabel('Cosine Value')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='lower right', frameon=False)
axes[0, 1].text(0, 0, 'I am [0, 1]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$e^{-x}\cos 5x$')
axes[1, 0].fill_between(x, fun1_x, 0, color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend()
axes[1, 0].text(0, 0, 'I am [1, 0]!', fontsize=30,
                horizontalalignment='center')

#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$e^{-x}\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].fill_between(x, fun2_x, 10, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].legend()
axes[1, 1].text(0, 0, 'I am [1, 1]!', fontsize=30,
                horizontalalignment='center')

# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)

# plt.tight_layout()
plt.show()

# %%
#To achieve in final version:
#Remove the text ‘I am..’
#Change the colours used for filling.
#Change the limits of the filled areas.
#Add titles to each subplot.
#Share the x axis across columns.
#Add/Remove labels to the x-axis.
#Make the tick labels of the two bottom plots the same.
#Add grids to all subplots.
#Add a legend to all subplots in the upper right position.
#Try to figure out what plt.tight_layout() does

# %%
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(24, 16), sharex=True, sharey='row')

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r',
                linestyle=':', label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].fill_between(x, cos_x, -1.25, color='r', alpha=.125)
axes[0, 0].legend(loc='upper right')

#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].fill_between(x, sin_x, -1.25, color='g', alpha=.125)
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_title('$\sin x$ & $\sin^2x$')
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].legend(loc='upper right')

#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$e^{-x}\cos 5x$')
axes[1, 0].fill_between(x, fun1_x, -25, color='b', alpha=.125)
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
axes[1, 0].legend()

#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$e^{-x}\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].set_xlabel('Angle (radians)')
axes[1, 1].fill_between(x, fun2_x, -25, color='y', alpha=.125)
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 1].legend()

for a in axes.flatten():
    a.grid(alpha=.5)

fig.tight_layout()
#after this instruction, graphs are closer to each other
plt.savefig('plotting_data_from_file.png', dpi=150)
plt.show()

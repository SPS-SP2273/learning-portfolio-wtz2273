# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Numerical Solutions (Need)</span></div>

# %% [markdown]
# ## 1 A Bucket of water

# %% [markdown]
# ### 1.1 Getting a feel

# %%
from matplotlib import pyplot as plt
max_time = 5
dt = .5
rate = 5
all_volume = []
volume = 0

all_time = np.arange(start=0, stop=max_time, step=dt)

for time in all_time:
    all_volume.append(volume)
    dV = rate * dt
    volume += dV
    
plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.show()

# %% [markdown]
# ### 1.2 An overflowing bucket

# %%
max_time = 5
dt = .5
rate = 5
bucket_capacity = 9
all_volume = []
volume = 0

all_time = np.arange(start=0, stop=max_time, step=dt)

for time in all_time:
    all_volume.append(volume)
    dV = rate * dt
    if volume <= bucket_capacity:
        volume += dV

plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')
plt.show()

# %%
max_time = 5
rate = 5
bucket_capacity = 9

for dt in [0.5, 0.1, 0.05, 0.01, 0.001]:
    all_volume = []
    volume = 0

    all_time = np.arange(start=0, stop=max_time, step=dt)

    for time in all_time:
        all_volume.append(volume)
        dV = rate * dt
        if volume <= bucket_capacity:
            volume += dV

    plt.plot(all_time, all_volume,label=f'dt={dt}')
    
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.3 A leaky bucket

# %%
max_time = 5
dt = .001
rate = 5
leak_rate = 1.5
bucket_capacity = 9
all_volume = []
volume = 0

all_time = np.arange(start=0, stop=max_time, step=dt)

for time in all_time:
    all_volume.append(volume)
    dV = rate * dt
    
    leak_volume = leak_rate * dt
    volume -= leak_volume

    if volume <= bucket_capacity:
        volume += dV

plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')
plt.show()

# %% [markdown]
# ### 1.4 Let’s turn off the tap

# %%
tap_off_time = 3
max_time = 5
dt = .001
rate = 5
leak_rate = 1.5
bucket_capacity = 9
all_volume = []
volume = 0

all_time = np.arange(start=0, stop=max_time, step=dt)

for time in all_time:
    all_volume.append(volume)
    dV = rate * dt
    
    leak_volume = leak_rate * dt
    volume -= leak_volume

    if (volume <= bucket_capacity) and (time < tap_off_time):
        volume += dV

plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')
plt.show()

# %% [markdown]
# ### Using while

# %%
tap_off_time = 3
max_time = 5
dt = .001
rate = 5
leak_rate = 1.5
bucket_capacity = 9
all_volume = []
all_time = []
volume = 0
time = 0

while time <= max_time:
    all_time.append(time)
    all_volume.append(volume)
    dV = rate * dt

    leak_volume = leak_rate * dt
    volume -= leak_volume

    if (volume <= bucket_capacity) and (time < tap_off_time):
        volume += dV

    time += dt
        
plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')
plt.show()

# %% [markdown]
# ### 1.5 A quick summary

# %% [markdown]
# 1. Establish a relationship that connects the changes of the variables.
# 1. Pick a starting value
# 1. Take a step, and calculate the changes.
# 1. Update the variables
# 1. Keep on going until you have the desired number of points.
# 1. If you want to improve accuracy, take smaller steps.

# %% [markdown]
# ### 1.6 We just solved a differential equation!

# %%
#dV/dt = R

# ΔV ~= RΔt

# %% [markdown]
# ## 2 Simulating Radioactivity

# %% [markdown]
# ### 2.1 Introduction

# %%
# dN/dt = −λN
# λ --> decay constant

# %% [markdown]
# ### 2.2 Approximating the differential equation

# %%
# ΔN ~= -λNΔt

# %% [markdown]
# ### 2.3 Getting a feel

# %%
# I am confident :)

# %% [markdown]
# ### 2.4 Let’s write some code

# %%
decay_constant = 142
stop_fraction = 1E-3

N0 = 1
dt = .001
time, N = 0, N0

all_N, all_time = [], []

while True:
    all_time.append(time)
    all_N.append(N)

    dN = -decay_constant*N*dt
    N += dN

    if N < N0*stop_fraction:
        break

    time += dt


plt.plot(all_time, all_N)
plt.ylabel('$N$')
plt.xlabel('Time(Millions of years)')
plt.show()

# %% [markdown]
# ### 2.5 Some things to note about the code

# %%
#use a True condition with the while loop
#we need to break out by ourselves
#before break, check N is negligible

# %% [markdown]
# ### 2.6 A quick summary

# %% [markdown]
# 1. Rewrite the equation in an approximate form that connects the changes of one variable to another.
# 1. Pick starting values for the variables.
# 1. Step the control variable (time in the previous case) and calculate the corresponding changes in the other variables.
# 1. Update the variables
# 1. Repeat until you reach the desired end.
# 1. Make the step size smaller if you want greater accuracy.

# %% [markdown]
# ## Exercise 1 :  A more realistic leak

# %%
Vol = 0
dt = .001
time, V = 0, Vol

all_V, all_time = [], []

while True:
    all_time.append(time)
    all_N.append(N)

    dN = -decay_constant*N*dt
    N += dN

    if N < N0*stop_fraction:
        break

    time += dt

# %%
import math

# %%
tap_off_time = 3
max_time = 5
dt = .001
rate = 5
all_volume = []
all_time = []
volume = 0
time = 0

leak_rate = 0.0001*math.sqrt(volume*196/7)

while True:
    all_time.append(time)
    all_volume.append(volume)
    dV = rate * dt

    leak_volume = leak_rate * dt
    volume -= leak_volume
    
    if volume<0:
        break

    time += dt
        
plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.show()
